# %% [markdown]
# When creating supervisor agent, I am not sure on how to implement guardrails, because there is not graph that I see...
#
# So I think we have to create a custorm supervisor agent... then add other nodes as agents... this should be the way...
#
# We have been using react agent, https://langchain-ai.github.io/langgraph/how-tos/react-agent-from-scratch/ - creating react agents seems to be same as ours.
